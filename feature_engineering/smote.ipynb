# %% [markdown]
# ## Synthetic Minority Oversampling Technique

# %%
# Intrpolating
from sklearn.datasets import make_classification

# %%
x,y=make_classification(
    n_samples=1000,
    n_redundant=0,
    n_features=2,
    n_clusters_per_class=1,
    weights=[0.90],
    random_state=12


)

# %%
import pandas as pd

df1 = pd.DataFrame(data=x, columns=['f1','f2'])
df2 = pd.DataFrame(data=y, columns=['target'])
final_df = pd.concat([df1,df2], axis=1)
final_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'], final_df['f2'], c=final_df['target'])

# %%
# !pip install imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\ilya\documents\data science course\.venv\lib\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\ilya\documents\data science course\.venv\lib\site-packages (from imblearn) (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\ilya\documents\data science course\.venv\lib\site-packages (from imbalanced-learn->imblearn) (2.3.4)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\ilya\documents\data science course\.venv\lib\site-packages (from imbalanced-learn->imblearn) (1.16.2)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\ilya\documents\data science course\.venv\lib\site-packages (from imbalanced-learn->imblearn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\ilya\documents\data science course\.venv\lib\site-packages (from imbalanced-learn->imblearn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\ilya\documents\data science course\.venv\lib\site-packages (from imbalanced-learn->imblearn) (3.6.0)

# %%
from imblearn.over_sampling import SMOTE

oversample = SMOTE()
x,y= oversample.fit_resample(final_df[['f1','f2']], final_df['target'])

# %%
x.shape
y.shape
# Out:
# (1800,)

# %%
df1 = pd.DataFrame(data=x, columns=['f1','f2'])
df2 = pd.DataFrame(data=y, columns=['target'])
oversample_df = pd.concat([df1,df2], axis=1)

# %%
plt.scatter(oversample_df['f1'], oversample_df['f2'], c=oversample_df['target'])
